# %% [markdown]
# <a href="https://colab.research.google.com/github/SPraveeen/python_google_colab_study/blob/main/Basics_of_time_and_space_complexity_Regex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
(3**7)
# Out:
# 2187

# %%
#find time completcity
# In terrms of input size 'N' we're going to find time complexity

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ***Rule 2 -> take the highest power of N for time completxity and ignore everything else***

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# **O(n+m**2) != O(m**2)**
#
# ---
#
#
# **O(n+n**2+n***3) -> O(n***3)**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
#
# **REGEX**
#
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#  "." matches all values
# "\." only matches .
# meta chara -> .{[(\^$|)
# \d {match all digits}
# \D (matches all except digits)
# \w {atches all alphanumeric char}
# \W {matches all except alphanumeric}
# \s {matches all white space/blankspace/newline}
# \S {matches everything apart from blank spaces}
####
#Anchor tag
# ab$ {end of string match}
# \b {atch ar starting word}
# \B { not matching at starting}
